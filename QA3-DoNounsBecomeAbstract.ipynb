# %% [markdown]
# # QA2-DoNounsBecomeAbstract

# %%
from koselleck import *

# %%
dfabs=get_dfpiv_abs().reset_index().melt(id_vars=['word'],value_name='abs')
dfabs['period2']=dfabs['period'].apply(lambda x: prdz(x, ystart=1700,ystep=10))
# dfabs['period2']=dfabs['period'].apply(lambda x: prdz(x, ystep=20))
dfabs=dfabs.groupby(['word','period2']).mean().reset_index().dropna()
dfabs
# Out:
#                word  period2       abs
# 8       abandonment     1780  1.327681
# 9       abandonment     1790  1.171656
# 10      abandonment     1800  2.413275
# 11      abandonment     1810  2.713879
# 12      abandonment     1820  2.842349
# ...             ...      ...       ...
# 120015      zoology     1850  0.007163
# 120016      zoology     1860  0.178568
# 120017      zoology     1870 -0.018641
# 120018      zoology     1880  0.091106
# 120019      zoology     1890 -0.035922
#
# [104703 rows x 3 columns]

# %%
pavg=dfabs[dfabs.word.isin(get_words_ever_abs())].groupby('period2').median().reset_index()
pavg['word']='(Singular nouns)'
pavg
# Out:
#     period2       abs              word
# 0      1700  1.030939  (Singular nouns)
# 1      1710  1.000036  (Singular nouns)
# 2      1720  1.142579  (Singular nouns)
# 3      1730  1.347240  (Singular nouns)
# 4      1740  1.368206  (Singular nouns)
# 5      1750  1.406359  (Singular nouns)
# 6      1760  1.408272  (Singular nouns)
# 7      1770  1.493862  (Singular nouns)
# 8      1780  1.564871  (Singular nouns)
# 9      1790  1.583538  (Singular nouns)
# 10     1800  1.641389  (Singular nouns)
# 11     1810  1.653130  (Singular nouns)
# 12     1820  1.624519  (Singular nouns)
# 13     1830  1.578139  (Singular nouns)
# 14     1840  1.545702  (Singular nouns)
# 15     1850  1.552415  (Singular nouns)
# 16     1860  1.532960  (Singular nouns)
# 17     1870  1.478914  (Singular nouns)
# 18     1880  1.479900  (Singular nouns)
# 19     1890  1.480084  (Singular nouns)

# %%
wdfabs=dfabs.groupby('word').mean().sort_values('abs')
wdfabs
# Out:
#             period2       abs
# word
# wood         1795.0 -2.380178
# bamboo       1830.0 -2.281229
# pond         1795.0 -2.278668
# top          1795.0 -2.269159
# hoop         1810.0 -2.247108
# ...             ...       ...
# religion     1795.0  2.621102
# prejudice    1795.0  2.649408
# sincerity    1795.0  2.713058
# moderation   1795.0  2.723789
# disregard    1810.0  3.004918
#
# [6001 rows x 2 columns]

# %%
# most conc
# wdfabs.head(25)

# %%
wdfabs.tail(25)
# Out:
#                    period2       abs
# word
# adherence      1800.000000  2.507115
# acquiescence   1820.000000  2.511550
# forbearance    1798.947368  2.512969
# toleration     1795.000000  2.515906
# patriotism     1810.000000  2.519277
# neglect        1795.000000  2.521629
# enlightenment  1855.000000  2.531120
# mankind        1795.000000  2.532336
# submission     1795.000000  2.533629
# belief         1795.000000  2.535848
# judgment       1795.000000  2.546927
# rectitude      1810.000000  2.549889
# censure        1795.000000  2.554411
# truth          1795.000000  2.558684
# injustice      1795.000000  2.559458
# mistrust       1840.000000  2.564494
# wisdom         1795.000000  2.571869
# ignorance      1795.000000  2.585165
# perversion     1820.000000  2.597215
# prudence       1795.000000  2.609850
# religion       1795.000000  2.621102
# prejudice      1795.000000  2.649408
# sincerity      1795.000000  2.713058
# moderation     1795.000000  2.723789
# disregard      1810.000000  3.004918

# %%
# most changing
dfc=get_classed_changes().sort_values('mean_diff_t_abs',ascending=False)
dfc=dfc[~dfc.mean_diff_t_abs.isnull()]
dfc=dfc[dfc.vector=='Abs-Conc.Median']
dfc.head(10)
# Out:
#                word           vector  change     mean1     mean2  mean_diff  \
# 113        reaction  Abs-Conc.Median   Abs++ -0.440711  1.762301   2.203012
# 146       admixture  Abs-Conc.Median    Abs+ -0.646893  0.638587   1.285480
# 154        bracelet  Abs-Conc.Median  Conc++  0.194306 -1.619311  -1.813617
# 169       precision  Abs-Conc.Median   Abs--  1.764828  0.847461  -0.917366
# 185            tact  Abs-Conc.Median   Abs++ -0.534747  1.485453   2.020200
# 208       intensity  Abs-Conc.Median   Abs++ -0.053995  1.277670   1.331665
# 230         anomaly  Abs-Conc.Median   Abs++ -0.084806  1.784910   1.869716
# 257  transportation  Abs-Conc.Median   Abs++ -0.732615  1.213708   1.946324
# 261    predominance  Abs-Conc.Median   Abs++  0.176976  1.713526   1.536550
# 350       fostering  Abs-Conc.Median   Abs++  0.135724  1.625134   1.489410
#
#      mean_diff_t    mean_diff_p  mean_diff_t_abs   len1  ...  \
# 113  -100.277296  3.140263e-164       100.277296  100.0  ...
# 146   -92.940437  2.732954e-159        92.940437  100.0  ...
# 154    92.415689  2.698883e-157        92.415689  100.0  ...
# 169    90.486754  1.029400e-158        90.486754  100.0  ...
# 185   -88.359024  2.498694e-154        88.359024  100.0  ...
# 208   -86.250567  2.019956e-154        86.250567  100.0  ...
# 230   -83.677013  1.893242e-149        83.677013  100.0  ...
# 257   -81.093505  8.846044e-148        81.093505  100.0  ...
# 261   -80.755173  2.199332e-144        80.755173  100.0  ...
# 350   -74.963381  3.205882e-142        74.963381  100.0  ...
#
#      neighborhood1_local  neighborhood2_local  score_diff_t_abstractness  \
# 113                  NaN                  NaN                        NaN
# 146                  NaN                  NaN                        NaN
# 154                  NaN                  NaN                        NaN
# 169                  NaN                  NaN                        NaN
# 185                  NaN                  NaN                        NaN
# 208                  NaN                  NaN                        NaN
# 230                  NaN                  NaN                        NaN
# 257                  NaN                  NaN                        NaN
# 261                  NaN                  NaN                        NaN
# 350                  NaN                  NaN                        NaN
#
#      score_diff_p_abstractness  class_abs  class_change  class_signif  class  \
# 113                        NaN        NaN           NaN           NaN    NaN
# 146                        NaN        NaN           NaN           NaN    NaN
# 154                        NaN        NaN           NaN           NaN    NaN
# 169                        NaN        NaN           NaN           NaN    NaN
# 185                        NaN        NaN           NaN           NaN    NaN
# 208                        NaN        NaN           NaN           NaN    NaN
# 230                        NaN        NaN           NaN           NaN    NaN
# 257                        NaN        NaN           NaN           NaN    NaN
# 261                        NaN        NaN           NaN           NaN    NaN
# 350                        NaN        NaN           NaN           NaN    NaN
#
#      mean_diff_abs  change_rank
# 113       2.203012            2
# 146       1.285480            1
# 154       1.813617            2
# 169       0.917366            2
# 185       2.020200            2
# 208       1.331665            2
# 230       1.869716            2
# 257       1.946324            2
# 261       1.536550            2
# 350       1.489410            2
#
# [10 rows x 43 columns]

# %%
dfc.change.value_counts()
# Out:
# +          2444
# -          1598
# Abs+        551
# Conc+       217
# Abs++       170
# Conc--      102
# Abs-         60
# Conc++       54
# Abs--        53
# Conc-        23
# Conc+++       5
# Abs+++        1
# Name: change, dtype: int64

# %%
dfc[dfc.change=='Abs--']
# Out:
#                 word           vector change     mean1     mean2  mean_diff  \
# 169        precision  Abs-Conc.Median  Abs--  1.764828  0.847461  -0.917366
# 1898             fee  Abs-Conc.Median  Abs--  1.013643 -0.125443  -1.139086
# 2239    preservation  Abs-Conc.Median  Abs--  2.128558  0.944704  -1.183854
# 2321        occasion  Abs-Conc.Median  Abs--  1.596098  0.955597  -0.640501
# 2697      succession  Abs-Conc.Median  Abs--  1.854464  0.754569  -1.099895
# 2729   accommodation  Abs-Conc.Median  Abs--  1.497972  0.292098  -1.205874
# 3151          safety  Abs-Conc.Median  Abs--  1.940644  0.773127  -1.167517
# 3295           filly  Abs-Conc.Median  Abs--  1.118732 -0.698154  -1.816886
# 3491        material  Abs-Conc.Median  Abs--  1.810560  0.623262  -1.187299
# 3996         majesty  Abs-Conc.Median  Abs--  1.200440  0.569550  -0.630890
# 4271         article  Abs-Conc.Median  Abs--  1.427602  0.526515  -0.901088
# 4908          affair  Abs-Conc.Median  Abs--  1.735629  0.864683  -0.870946
# 5104         kingdom  Abs-Conc.Median  Abs--  1.530554  0.751800  -0.778754
# 5786           glory  Abs-Conc.Median  Abs--  2.035071  0.854967  -1.180104
# 6205           thing  Abs-Conc.Median  Abs--  1.417385  0.643560  -0.773825
# 6220            mutt  Abs-Conc.Median  Abs--  1.795304  0.234212  -1.561092
# 6327     performance  Abs-Conc.Median  Abs--  1.822015  0.999363  -0.822652
# 6746        ornament  Abs-Conc.Median  Abs--  1.025640 -0.320660  -1.346300
# 6892          person  Abs-Conc.Median  Abs--  1.294053  0.902289  -0.391764
# 7182        commerce  Abs-Conc.Median  Abs--  1.559648  0.964832  -0.594816
# 7880          design  Abs-Conc.Median  Abs--  2.169819  0.837351  -1.332467
# 8615           ledge  Abs-Conc.Median  Abs--  1.380707 -0.633313  -2.014020
# 8696             ion  Abs-Conc.Median  Abs--  1.167943  0.551448  -0.616495
# 8760        business  Abs-Conc.Median  Abs--  1.658064  0.818276  -0.839788
# 9523          throne  Abs-Conc.Median  Abs--  1.087472  0.452064  -0.635408
# 9574       discovery  Abs-Conc.Median  Abs--  1.464746  0.550751  -0.913995
# 10046          style  Abs-Conc.Median  Abs--  1.460018  0.753437  -0.706580
# 10061     magistrate  Abs-Conc.Median  Abs--  1.711898  0.782065  -0.929833
# 10413         heaven  Abs-Conc.Median  Abs--  1.384691  0.543344  -0.841348
# 10703           king  Abs-Conc.Median  Abs--  1.079408  0.554157  -0.525251
# 11658    countenance  Abs-Conc.Median  Abs--  1.441692  0.635893  -0.805799
# 11884     perfection  Abs-Conc.Median  Abs--  1.510239  0.892363  -0.617876
# 12195       strength  Abs-Conc.Median  Abs--  1.674148  0.976475  -0.697673
# 13421        monarch  Abs-Conc.Median  Abs--  1.648839  0.983364  -0.665475
# 13617         father  Abs-Conc.Median  Abs--  1.194123  0.689075  -0.505048
# 13854    application  Abs-Conc.Median  Abs--  2.079714  0.926894  -1.152821
# 13863         series  Abs-Conc.Median  Abs--  1.187862  0.372117  -0.815745
# 14000          title  Abs-Conc.Median  Abs--  1.378168  0.884920  -0.493248
# 14648           soul  Abs-Conc.Median  Abs--  1.555405  0.802187  -0.753218
# 15509  specification  Abs-Conc.Median  Abs--  1.256791  0.201011  -1.055780
# 16560           care  Abs-Conc.Median  Abs--  1.228246  0.581360  -0.646886
# 17258          party  Abs-Conc.Median  Abs--  1.583988  0.868104  -0.715884
# 17516   conversation  Abs-Conc.Median  Abs--  1.575016  0.885366  -0.689650
# 18933       creature  Abs-Conc.Median  Abs--  1.061981  0.175181  -0.886800
# 19312         friend  Abs-Conc.Median  Abs--  1.161508  0.570263  -0.591245
# 20503         relief  Abs-Conc.Median  Abs--  1.004374  0.563551  -0.440823
# 20601        balance  Abs-Conc.Median  Abs--  1.228104  0.588994  -0.639110
# 21283        bulwark  Abs-Conc.Median  Abs--  1.094372  0.352988  -0.741384
# 21316          demon  Abs-Conc.Median  Abs--  1.085643  0.336136  -0.749507
# 21460        trouble  Abs-Conc.Median  Abs--  1.168319  0.819987  -0.348331
# 21738       stranger  Abs-Conc.Median  Abs--  1.079316  0.290734  -0.788582
# 21817         feeing  Abs-Conc.Median  Abs--  1.462771  0.250685  -1.212086
# 21889       elegance  Abs-Conc.Median  Abs--  1.264890  0.738613  -0.526277
#
#        mean_diff_t    mean_diff_p  mean_diff_t_abs   len1  ...  \
# 169      90.486754  1.029400e-158        90.486754  100.0  ...
# 1898     47.811352  4.265790e-106        47.811352  100.0  ...
# 2239     45.422154  3.618241e-102        45.422154  100.0  ...
# 2321     44.988921   3.206897e-99        44.988921  100.0  ...
# 2697     43.049670   6.773761e-93        43.049670  100.0  ...
# 2729     42.902598   5.859135e-94        42.902598  100.0  ...
# 3151     41.000910   2.308963e-94        41.000910  100.0  ...
# 3295     40.382077   1.358471e-91        40.382077  100.0  ...
# 3491     39.634336   2.139040e-88        39.634336  100.0  ...
# 3996     37.989682   1.078325e-87        37.989682  100.0  ...
# 4271     37.048949   3.334507e-87        37.048949  100.0  ...
# 4908     35.349663   3.068832e-81        35.349663  100.0  ...
# 5104     34.929062   8.871549e-80        34.929062  100.0  ...
# 5786     33.300285   1.786856e-77        33.300285  100.0  ...
# 6205     32.399768   4.590609e-73        32.399768  100.0  ...
# 6220     32.373931   4.499786e-74        32.373931  100.0  ...
# 6327     32.183520   2.360718e-75        32.183520  100.0  ...
# 6746     31.469505   6.488720e-72        31.469505  100.0  ...
# 6892     31.216822   4.186383e-74        31.216822  100.0  ...
# 7182     30.724820   4.192948e-72        30.724820  100.0  ...
# 7880     29.596137   7.690894e-67        29.596137  100.0  ...
# 8615     28.517066   2.508739e-62        28.517066  100.0  ...
# 8696     28.426108   2.417873e-57        28.426108  100.0  ...
# 8760     28.339264   7.737183e-64        28.339264  100.0  ...
# 21817                        NaN        NaN           NaN           NaN
# 21889                        NaN        NaN           NaN           NaN
#
#        class  mean_diff_abs  change_rank
# 169      NaN       0.917366            2
# 1898     NaN       1.139086            2
# 2239     NaN       1.183854            2
# 2321     NaN       0.640501            2
# 2697     NaN       1.099895            2
# 2729     NaN       1.205874            2
# 3151     NaN       1.167517            2
# 3295     NaN       1.816886            2
# 3491     NaN       1.187299            2
# 3996     NaN       0.630890            2
# 4271     NaN       0.901088            2
# 4908     NaN       0.870946            2
# 5104     NaN       0.778754            2
# 5786     NaN       1.180104            2
# 6205     NaN       0.773825            2
# 6220     NaN       1.561092            2
# 6327     NaN       0.822652            2
# 6746     NaN       1.346300            2
# 6892     NaN       0.391764            2
# 7182     NaN       0.594816            2
# 7880     NaN       1.332467            2
# 8615     NaN       2.014020            2
# 8696     NaN       0.616495            2
# 8760     NaN       0.839788            2
# 9523     NaN       0.635408            2
# 9574     NaN       0.913995            2
# 10046    NaN       0.706580            2
# 10061    NaN       0.929833            2
# 10413    NaN       0.841348            2
# 10703    NaN       0.525251            2
# 11658    NaN       0.805799            2
# 11884    NaN       0.617876            2
# 12195    NaN       0.697673            2
# 13421    NaN       0.665475            2
# 13617    NaN       0.505048            2
# 13854    NaN       1.152821            2
# 13863    NaN       0.815745            2
# 14000    NaN       0.493248            2
# 14648    NaN       0.753218            2
# 15509    NaN       1.055780            2
# 16560    NaN       0.646886            2
# 17258    NaN       0.715884            2
# 17516    NaN       0.689650            2
# 18933    NaN       0.886800            2
# 19312    NaN       0.591245            2
# 20503    NaN       0.440823            2
# 20601    NaN       0.639110            2
# 21283    NaN       0.741384            2
# 21316    NaN       0.749507            2
# 21460    NaN       0.348331            2
# 21738    NaN       0.788582            2
# 21817    NaN       1.212086            2
# 21889    NaN       0.526277            2
#
# [53 rows x 43 columns]

# %%
@interact
def plot(words='''culture,interest,train,citizen,religion,leather''',smooth=2):
    if type(words)==str:
        words={w.strip().lower() for w in words.split(',') if w.strip()}
    figdf=dfabs[dfabs.word.isin(words)]
    figdf=figdf.append(pavg)
    
    figdf=pd.concat(
        grp.set_index(['word','period2']).sort_index().rolling(smooth,min_periods=1).mean().reset_index()
        for w,grp in figdf.groupby('word')
    )
    
    
    fig=start_fig(
        figdf,
        x='period2',
        y='abs',
        group='word',
        color='word',
        figure_size=(8,5)
    )
    fig+=p9.geom_hline(yintercept=0)
    fig+=p9.geom_line(p9.aes(color='word'),size=1)
    fig+=p9.geom_point(p9.aes(color='word'),size=1)
    fig+=p9.scale_color_brewer(type='qual',palette=3)
    
    fig+=p9.geom_label(p9.aes(label='word'),size=8,data=figdf[figdf.period2==figdf.period2.max()])
    fig.save('figures/fig.few_words_w_singnouns.png')
    return fig
# Out:
# interactive(children=(Text(value='culture,interest,train,citizen,religion,leather', description='words'), IntS…

# %%
dfc[dfc.change=='Abs++']
# Out:
#                  word           vector change     mean1     mean2  mean_diff  \
# 113          reaction  Abs-Conc.Median  Abs++ -0.440711  1.762301   2.203012
# 185              tact  Abs-Conc.Median  Abs++ -0.534747  1.485453   2.020200
# 208         intensity  Abs-Conc.Median  Abs++ -0.053995  1.277670   1.331665
# 230           anomaly  Abs-Conc.Median  Abs++ -0.084806  1.784910   1.869716
# 257    transportation  Abs-Conc.Median  Abs++ -0.732615  1.213708   1.946324
# ...               ...              ...    ...       ...       ...        ...
# 20364        transfer  Abs-Conc.Median  Abs++  0.123537  1.306005   1.182468
# 20674        reformer  Abs-Conc.Median  Abs++  0.486439  2.002554   1.516115
# 20824      fellowship  Abs-Conc.Median  Abs++  0.456719  1.399121   0.942402
# 20975         privacy  Abs-Conc.Median  Abs++  0.405164  1.188779   0.783616
# 21516         chagrin  Abs-Conc.Median  Abs++  0.397978  1.291674   0.893696
#
#        mean_diff_t    mean_diff_p  mean_diff_t_abs   len1  ...  \
# 113    -100.277296  3.140263e-164       100.277296  100.0  ...
# 185     -88.359024  2.498694e-154        88.359024  100.0  ...
# 208     -86.250567  2.019956e-154        86.250567  100.0  ...
# 230     -83.677013  1.893242e-149        83.677013  100.0  ...
# 257     -81.093505  8.846044e-148        81.093505  100.0  ...
# ...            ...            ...              ...    ...  ...
# 20364   -18.754378   1.884221e-36        18.754378  100.0  ...
# 20674   -18.560090   4.450806e-38        18.560090  100.0  ...
# 20824   -18.493394   1.270522e-41        18.493394  100.0  ...
# 20975   -18.421194   2.452099e-38        18.421194  100.0  ...
# 21516   -18.149436   1.747300e-38        18.149436  100.0  ...
#
#        neighborhood1_local  neighborhood2_local  score_diff_t_abstractness  \
# 113                    NaN                  NaN                        NaN
# 185                    NaN                  NaN                        NaN
# 208                    NaN                  NaN                        NaN
# 230                    NaN                  NaN                        NaN
# 257                    NaN                  NaN                        NaN
# ...                    ...                  ...                        ...
# 20364                  NaN                  NaN                        NaN
# 20674                  NaN                  NaN                        NaN
# 20824                  NaN                  NaN                        NaN
# 20975                  NaN                  NaN                        NaN
# 21516                  NaN                  NaN                        NaN
#
#        score_diff_p_abstractness  class_abs  class_change  class_signif  \
# 113                          NaN        NaN           NaN           NaN
# 185                          NaN        NaN           NaN           NaN
# 208                          NaN        NaN           NaN           NaN
# 230                          NaN        NaN           NaN           NaN
# 257                          NaN        NaN           NaN           NaN
# ...                          ...        ...           ...           ...
# 20364                        NaN        NaN           NaN           NaN
# 20674                        NaN        NaN           NaN           NaN
# 20824                        NaN        NaN           NaN           NaN
# 20975                        NaN        NaN           NaN           NaN
# 21516                        NaN        NaN           NaN           NaN
#
#        class  mean_diff_abs  change_rank
# 113      NaN       2.203012            2
# 185      NaN       2.020200            2
# 208      NaN       1.331665            2
# 230      NaN       1.869716            2
# 257      NaN       1.946324            2
# ...      ...            ...          ...
# 20364    NaN       1.182468            2
# 20674    NaN       1.516115            2
# 20824    NaN       0.942402            2
# 20975    NaN       0.783616            2
# 21516    NaN       0.893696            2
#
# [170 rows x 43 columns]

# %%
plot_word_info('pattern')
# Out:
# ## pattern
# * Data from Sattelzeit binary model comparison
#     * **Noisy** result for semantic change according to the noise aware data
#     * **96%** (**~Noisy**) percentile for <u>local semantic change</u> (z=2.2)
# * Its neighborhoods:
#
**</u> (8), <u>**+seam**</u> (8), <u>**+fringe**</u> (8), <u>**+cornice**</u> (8), <u>**+carving**</u> (8), <u>**+collar**</u> (7), <u>**+carpet**</u> (7), <u>**+button**</u> (7), <u>**+comb**</u> (7), <u>**+buff**</u> (6), <u>**+porcelain**</u> (6), <u>**+wool**</u> (6), <u>**+metal**</u> (6), <u>**+thread**</u> (6), <u>**+loop**</u> (5), <u>**+pendant**</u> (5), <u>**+brass**</u> (5), <u>**+hoop**</u> (5), <u>**+plate**</u> (4), <u>**+jacket**</u> (4), <u>**+worsted**</u> (4), <u>**+cushion**</u> (4), <u>**+pin**</u> (4), <u>**+girdle**</u> (3), <u>**+device**</u> (3), <u>**+dress**</u> (2), fashion (2), <u>**+size**</u> (2), <u>**+cord**</u> (2), <u>**+toilet**</u> (2), <u>**+pewter**</u> (2), <u>**+satin**</u> (2), <u>**+cement**</u> (2), imitation (2), <u>**+muslin**</u> (2), <u>**+scroll**</u> (2), <u>**+gown**</u> (2) |
#
# * Its changes along key vectors categorized:
#                                 change mean_diff  mean1  mean2  mean_diff_t  \
# word    vector
# pattern Human-Object.VG      Object+++     -2.55   1.06  -1.49        34.02
#         Active-Passive.HGI   Active+++      +2.3  -1.03   1.27       -35.02
#         Abs-Conc.Median        Conc+++     -2.13   1.06  -1.07        39.82
#         Interp-Desc.HGI       Interp--     -1.11   1.16   0.04        21.19
#         Strong-Weak.HGI       Strong++     +1.06   0.36   1.42       -18.56
#         Collective-Indiv.RH     Indiv+     -1.47   0.86  -0.61        19.53
#         Freq.M                   Freq+      +0.2  -0.27  -0.07       -20.38
#         Time-Space.HGI               -     -1.22  -0.11  -1.33        15.90
#         Woman-Man.VG                 +     +0.72   0.43   1.15        -6.35
#         Pos-Neg.HGI                  -     -0.69   2.42   1.73         5.82
#         Judg-Perc.HGI                -     -0.57   0.17  -0.40         7.51
#         Virtue-Vice.HGI              -     -0.57   2.51   1.93         4.54
#         Pleasure-Pain.HGI            -     -0.24   2.23   1.99         1.67
#         Polit-Acad.HGI               +     +0.21  -0.96  -0.75        -4.34
#         Qual-Quant.HGI               -     -0.14   0.22   0.08         2.80
#         Sing-Plural.M                +     +0.07  -0.30  -0.23        -7.87
#         Ambig.NX                     -     -0.02   0.53   0.51         0.18
#
#                              mean_diff_p   perc
# word    vector
# pattern Human-Object.VG             0.00  93.78
#         Active-Passive.HGI          0.00  94.23
#         Abs-Conc.Median             0.00  96.07
#         Interp-Desc.HGI             0.00  81.28
#         Strong-Weak.HGI             0.00  76.43
#         Collective-Indiv.RH         0.00  78.36
#         Freq.M                      0.00  79.90
#         Time-Space.HGI              0.00  70.19
#         Woman-Man.VG                0.00  33.83
#         Pos-Neg.HGI                 0.00  31.20
#         Judg-Perc.HGI               0.00  39.37
#         Virtue-Vice.HGI             0.00  24.61
#         Pleasure-Pain.HGI           0.22   8.91
#         Polit-Acad.HGI              0.00  23.63
#         Qual-Quant.HGI              0.06  15.26
#         Sing-Plural.M               0.00  41.09
#         Ambig.NX                    0.48   2.07
# * These changes visualized:
# <ggplot: (8746437361505)>

# %%
dfc[dfc.change=='Conc+++']
# Out:
#          word           vector   change     mean1     mean2  mean_diff  \
# 781      muff  Abs-Conc.Median  Conc+++  1.859496 -1.438977  -3.298474
# 1979   fettle  Abs-Conc.Median  Conc+++  1.246778 -1.201397  -2.448175
# 2623    stile  Abs-Conc.Median  Conc+++  1.070456 -1.652747  -2.723202
# 3449  pattern  Abs-Conc.Median  Conc+++  1.063894 -1.068987  -2.132881
# 5980    slate  Abs-Conc.Median  Conc+++  1.186055 -1.849539  -3.035595
#
#       mean_diff_t    mean_diff_p  mean_diff_t_abs   len1  ...  \
# 781     61.163506  2.427243e-126        61.163506  100.0  ...
# 1979    47.269757  6.289820e-103        47.269757  100.0  ...
# 2623    43.354829   1.146757e-91        43.354829  100.0  ...
# 3449    39.818603   5.045284e-90        39.818603  100.0  ...
# 5980    32.859035   1.286730e-77        32.859035  100.0  ...
#
#       neighborhood1_local  neighborhood2_local  score_diff_t_abstractness  \
# 781                   NaN                  NaN                        NaN
# 1979                  NaN                  NaN                        NaN
# 2623                  NaN                  NaN                        NaN
# 3449                  NaN                  NaN                        NaN
# 5980                  NaN                  NaN                        NaN
#
#       score_diff_p_abstractness  class_abs  class_change  class_signif  class  \
# 781                         NaN        NaN           NaN           NaN    NaN
# 1979                        NaN        NaN           NaN           NaN    NaN
# 2623                        NaN        NaN           NaN           NaN    NaN
# 3449                        NaN        NaN           NaN           NaN    NaN
# 5980                        NaN        NaN           NaN           NaN    NaN
#
#       mean_diff_abs  change_rank
# 781        3.298474            3
# 1979       2.448175            3
# 2623       2.723202            3
# 3449       2.132881            3
# 5980       3.035595            3
#
# [5 rows x 43 columns]

# %%
dfc[dfc.word=='station']
# Out:
#           word           vector change     mean1     mean2  mean_diff  \
# 27887  station  Abs-Conc.Median      -  0.908937 -0.363135  -1.272072
#
#        mean_diff_t   mean_diff_p  mean_diff_t_abs   len1  ...  \
# 27887    15.166461  1.367039e-26        15.166461  100.0  ...
#
#        neighborhood1_local  neighborhood2_local  score_diff_t_abstractness  \
# 27887                  NaN                  NaN                        NaN
#
#        score_diff_p_abstractness  class_abs  class_change  class_signif  \
# 27887                        NaN        NaN           NaN           NaN
#
#        class  mean_diff_abs  change_rank
# 27887    NaN       1.272072            0
#
# [1 rows x 43 columns]

# %%
words=[
    'labourer',
    'reform',
    'catastrophe',
    'demand',
#     'insurrection',
#         'value',
#     'institution',
    'circulation',
    'slave',
    'service',
#         'revolution',
#         'formula',
#         'slavery',
        'example',
#         'citizen',
        'interest',
#         'workmanship',
        'vehicle',
#         'disease',
#     'relationship'
]
len(words)
# Out:
# 10

# %%
plot(words)
# stop
# Out:
# <ggplot: (8746436728957)>

# %%
plot(dfc[dfc.change=='Abs++'].word.sample(n=5))

# %%
plot(dfc[dfc.change=='Conc++'].word.sample(n=5))

# %%
plot(get_keywords().reset_index().word.sample(n=5))

# %%
dfkw=get_keywords()

# %%
wdfabs2=wdfabs.merge(dfkw,on='word').reset_index().drop_duplicates('word').sort_values('abs').set_index('word')
wdfabs2

# %%
wdfabs2.tail(25)

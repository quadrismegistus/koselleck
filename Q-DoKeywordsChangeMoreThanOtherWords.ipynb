# %%
from koselleck import *

# %%
get_decade_level_data()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-378867c893a4> in <module>
# ----> 1 get_decade_level_data()
#
# ~/github/koselleck/koselleck/tools.py in get_decade_level_data(words, z)
#      66     # load decade level data
#      67     if words is None: words=get_valid_words()
# ---> 68     dfpiv_abs=get_dfpiv_abs(words,z=z).dropna()
#      69     words=set(dfpiv_abs.index)
#      70     dfpiv_freq=get_dfpiv_freq(words,z=z).dropna()
#
# ~/github/koselleck/koselleck/tools.py in get_dfpiv_abs(key, **y)
#     162
#     163 def get_dfpiv_abs(key=FIELD_ABS_KEY,**y):
# --> 164     return get_dfpiv(key)
#     165
#     166
#
# ~/github/koselleck/koselleck/tools.py in get_dfpiv(key, fn, ymin, ymax)
#     157     pwdf['period']=[int(p[:4]) for p in pwdf.period]
#     158     pwdf=pwdf.query(f'{ymin}<=period<{ymax}')
# ...

# %%
iplot_word_info()
# Out:
# interactive(children=(Text(value='culture', description='w'), Output()), _dom_classes=('widget-interact',))
# <function koselleck.plots.plot_word_info(w)>

# %%
mostchanged = get_dfchange(words=get_keywords()).index
len(mostchanged)
# Out:
# 52

# %%
for i,w in enumerate(mostchanged):
    plot_word_info(w)
# Out:
# ## career
# * **97%** (**~Noisy**) percentile for local semantic change (z=2.85)
# * **95%** (**+Abstract**) percentile for magnitude change in abstractness (z=1.99): 0.01 -> 0.93
# * **Noisy** result according to the noise aware data
# * Its neighborhoods:
#
# | Neighborhood 1 | Neighborhood 2 |
# | -------------- | -------------- |
# ...

# %%
interact(plot_word_info, w='culture')
# Out:
# interactive(children=(Text(value='culture', description='w'), Output()), _dom_classes=('widget-interact',))
# <function koselleck.plots.plot_word_info(w)>

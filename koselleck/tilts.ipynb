# %% [markdown]
# # Computing key vectors across models

# %%
from ipynb.fs.full.koselleck import *
# Out:
# [Koselleck] (11:22:25) Alles bereit

# %%
#dfmodels = get_default_models()
# dfmodels

# %%
# row=dfmodels.sample(n=1).iloc[0]
# m=load_model_row(row)
# row.period, row.run, m

# %%
# Defining key vectors

# field dictionary
fieldd=get_fields()

def get_misccontrasts(fieldd=None):
    if fieldd is None: fieldd=get_fields()
    return [{
        'contrast':'Woman-Man',
        'source':'VG',
        'pos':fieldd['VG.Human.Female'],
        'neg':fieldd['VG.Human.Male'],
    },
    {
        'contrast':'Human-Object',
        'source':'VG',
        'pos':fieldd['VG.Human'],
        'neg':fieldd['VG.Object'],
    },
    {
        'contrast':'Pleasure-Pain',
        'source':'HGI',
        'pos':fieldd['HGI.Pleasur'],
        'neg':fieldd['HGI.Pain'],
    },
    {
        'contrast':'Interp-Desc',
        'source':'HGI',
        'pos':fieldd['HGI.IAV'],
        'neg':fieldd['HGI.DAV'],
    },
    {
        'contrast':'Polit-Acad',
        'source':'HGI',
        'pos':fieldd['HGI.Polit@'],
        'neg':fieldd['HGI.Academ'],
    },
    {
        'contrast':'Qual-Quant',
        'source':'HGI',
        'pos':fieldd['HGI.Quality'],
        'neg':fieldd['HGI.Quan'],
    },
#     {
#         'contrast':'Time',
#         'source':'HGI',
#         'pos':fieldd['HGI.Time@'],
#     },
    {
        'contrast':'Time-Space',
        'source':'HGI',
        'pos':fieldd['HGI.Time@'],
        'neg':fieldd['HGI.Space'],
    },
    {
        'contrast':'Pos-Neg',
        'source':'HGI',
        'period':'na',
        'pos':fieldd['HGI.Pstv'],
        'neg':fieldd['HGI.Ngtv'],
        'neither':{}
    },
    {
        'contrast':'Virtue-Vice',
        'source':'HGI',
        'period':'na',
        'pos':fieldd['HGI.Virtue'],
        'neg':fieldd['HGI.Vice'],
        'neither':{}
    },
    {
        'contrast':'Collective-Indiv',
        'source':'RH',
        'period':'na',
        'pos':{'society','world','public','publicity','polity'},
        'neg':{'individual','person','private','privacy'},
        'neither':{}
    },
    {
        'contrast':'Judg-Perc',
        'source':'HGI',
        'period':'na',
        'pos':fieldd['HGI.Eval@'],
        'neg':fieldd['HGI.Perceiv'],
        'neither':{}
    },
    {
        'contrast':'Strong-Weak',
        'source':'HGI',
        'period':'na',
        'pos':fieldd['HGI.Strong'],
        'neg':fieldd['HGI.Weak'],
        'neither':{}
    },
    {
        'contrast':'Active-Passive',
        'source':'HGI',
        'period':'na',
        'pos':fieldd['HGI.Active'],
        'neg':fieldd['HGI.Passive'],
        'neither':{}
    },
    ]

# %%
def get_key_contrasts():
    origc=[cd for cd in get_origcontrasts().to_dict('records') if cd['source']=='Median']
    for dx in origc: dx['pos'],dx['neg'] = dx['neg'],dx['pos']
    miscc=get_misccontrasts()
    return origc + miscc

# %%
# pd.DataFrame(get_key_contrasts())

# %%
def get_centroid(model,words):
    words=[words] if type(words)==str else list(words)
    vectors=[]
    for w in words:
        if w in model.wv.key_to_index:
            vectors+=[model.wv[w]]
    if not vectors: return None
    return np.mean(vectors,0)

def compute_vector(model,words_pos=[],words_neg=[]):
    centroid_pos=get_centroid(model,words_pos)
    if not words_neg: return centroid_pos
    centroid_neg=get_centroid(model,words_neg)
    if centroid_neg is not None:
        return centroid_pos - centroid_neg
    else:
        return centroid_pos

def compute_vector_scores(m,pos,neg=None,z=True):
    vec=np.array(compute_vector(m,pos,neg), dtype=np.float64)
    matrix=np.array(m.wv.get_normed_vectors(),dtype=np.float64)
    res=fastdist.vector_to_matrix_distance(vec,matrix,fastdist.cosine,'cosine')
    resd=dict((m.wv.index_to_key[i],x)for i,x in enumerate(res))
    s=pd.Series(resd)
    if z: s=(s - s.mean())/s.std()
    return s.sort_values()

# %%
def compute_key_vector_scores(m,fieldd=None,words=None):
    # get fields
    if fieldd is None: fieldd=get_fields()
    abswordseed=fieldd['Abs-Conc.Median.Abs.orig']
    concwordseed=fieldd['Abs-Conc.Median.Conc.orig']
    odf=pd.DataFrame()
    for cd in get_key_contrasts():
        odf[cd['contrast']+'.'+cd['source']] = compute_vector_scores(m, cd.get('pos',{}), cd.get('neg',{}))
    odf=odf.rename_axis('word').reset_index()
    if words: odf=odf[odf.word.isin(set(words))]
    return odf.set_index('word')

# %%
# dfvec=compute_key_vector_scores(m, words=get_valid_words()).sort_values('Collective-Indiv.RH')
# dfvec

# %%
# for col in dfvec.columns:
#     printm('### '+col)
#     printm('* Positive: '+ ', '.join(dfvec[col].sort_values(ascending=False).iloc[:10].index))
#     printm('* Negative: '+ ', '.join(dfvec[col].sort_values(ascending=True).iloc[:10].index))

# %%
# dfvec.corr().sort_values('Collective-Indiv.RH')

# %%
def compute_key_vector_scores_across_models(pathdf,words=None,num_proc=1,**attrs):
    #gby=[c for c in pathdf.columns if not c.startswith('path')]
    gby=['corpus','period','run']
    return pmap_groups(
        do_compute_all_vectors,
        pathdf.groupby(gby),
        num_proc=num_proc,
        kwargs=dict(words=words),
        desc='Computing key vectors across model runs'
    )
def do_compute_all_vectors(df,words=None,add_ambig=True, add_freq=True, add_sing=True):
    m=load_model_row(df.iloc[0])
    odf=compute_key_vector_scores(m,words=words)#.reset_index()
    if add_ambig: odf['Ambig.NX']=measure_ambiguity(m,words=words,z=True)
    if add_freq: odf['Freq.M']=measure_freq(m,words=words, z=True)
    if add_sing: odf['Sing-Plural.M']=measure_singularism(m,words=words,z=True)['freq_diff']
    return odf.reset_index()

# %%
# for i,gdf in dfmodels.groupby(['corpus','period','run']): pass

# %%
# words=get_all_nouns_adjs()

# %%
# ogdf=do_compute_all_vectors(gdf,words=words, add_ambig=True).sort_values('Sing-Plural.M')
# ogdf

# %%
# odf=compute_key_vector_scores_across_models(
#     dfmodels,#.query('run<="run_10"'),
#     words=words,
#     num_proc=4,
# )
# odf.to_pickle(FN_VECTOR_SCORES_RUNS)
# odf

# %%
# odf.groupby('word').mean().sort_values('Qual-Quant.HGI')

# %% [markdown]
# ## Utilities

# %%
def get_words_ever_abs(fn=FN_VECTOR_SCORES_RUNS,cutoff=1):
    df=read_df(fn)
    wea=df.groupby(['period','word']).mean().reset_index()
    wea=wea[wea['Abs-Conc.Median']>=cutoff]
    wea=set(wea.word)
    return wea
#     len(wea),random.sample(wea,10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b12222598f27> in <module>
# ----> 1 def get_words_ever_abs(fn=FN_VECTOR_SCORES_RUNS,cutoff=1):
#       2     df=read_df(fn)
#       3     wea=df.groupby(['period','word']).mean().reset_index()
#       4     wea=wea[wea['Abs-Conc.Median']>=cutoff]
#       5     wea=set(wea.word)
#
# NameError: name 'FN_VECTOR_SCORES_RUNS' is not defined

# %%
len(get_words_ever_abs(cutoff=2))
# Out:
# 1471

# %%
stop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-4f76a9dad686> in <module>
# ----> 1 stop
#
# NameError: name 'stop' is not defined

# %%
def get_vector_scores(fn=FN_VECTOR_SCORES_RUNS,force=False):
    global DFVECSCORES
    if DFVECSCORES is None or force:
        df = read_df(fn).reset_index()
        df['period_int']=df.period.apply(lambda x: int(x[:4]))
        df['period_str']=df['period']
        df['period']=df.period_int.apply(periodize_sattelzeit)
        DFVECSCORES=df
    return DFVECSCORES#.groupby(['word','period']).mean()

# %% [markdown]
# ## Comparisons

# %%
# %%timeit
df=get_vector_scores(force=False)

# %%
df[df.word=='virtue']
# Out:
#         corpus     period     run    word  Abs-Conc.Median  Woman-Man.VG  \
# 6890       bpo  1700-1770  run_01  virtue         3.214739     -0.055065
# 13793      bpo  1700-1770  run_02  virtue         3.426751     -0.575663
# 20768      bpo  1700-1770  run_03  virtue         3.285548      1.083244
# 27674      bpo  1700-1770  run_04  virtue         3.090393      1.627666
# 34645      bpo  1700-1770  run_05  virtue         2.864174      0.091354
# ...        ...        ...     ...     ...              ...           ...
# 3489011    bpo  1830-1900  run_06  virtue         2.075567      0.081599
# 3500193    bpo  1830-1900  run_07  virtue         2.040826     -0.015448
# 3511774    bpo  1830-1900  run_08  virtue         2.446604      0.236667
# 3522818    bpo  1830-1900  run_09  virtue         2.116359      0.783226
# 3533395    bpo  1830-1900  run_10  virtue         1.644468     -0.194101
#
#          Human-Object.VG  Pleasure-Pain.HGI  Interp-Desc.HGI  Polit-Acad.HGI  \
# 6890            1.381495           2.572173         2.845677        1.558998
# 13793           2.026422           3.071403         3.055524        1.234054
# 20768           1.714781           2.420538         2.791909        1.790631
# 27674           1.881941           1.783067         2.609544        1.351938
# 34645           1.674049           2.071734         2.518239        1.389316
# ...                  ...                ...              ...             ...
# 3489011         1.128639           1.710345         1.406778       -1.219324
# 3500193         1.149327           1.871244         1.653688       -0.984135
# 3511774         1.871441           1.457747         1.879064       -0.553039
# 3522818         1.321273           1.838180         1.898465       -0.730975
# 3533395         0.950671           1.503685         1.283423       -0.666407
#
#          ...  Virtue-Vice.HGI  Collective-Indiv.RH  Judg-Perc.HGI  \
# 6890     ...         2.805773             1.113559       0.046696
# 13793    ...         3.345770             0.401270      -0.324064
# 20768    ...         2.765761             1.978974       0.215037
# 27674    ...         2.420377             0.445426      -0.509606
# 34645    ...         1.980953             1.054147      -0.099164
# ...      ...              ...                  ...            ...
# 3489011  ...         2.402779            -0.545846      -2.313037
# 3500193  ...         2.663170             0.068328      -1.312321
# 3511774  ...         2.196886            -0.368364      -1.410475
# 3522818  ...         2.270594             0.367582      -1.046473
# 3533395  ...         2.057910             0.040414      -1.676688
#
#          Strong-Weak.HGI  Active-Passive.HGI  Ambig.NX    Freq.M  \
# 6890            2.234454           -2.549791  0.298927  1.268937
# 13793           2.097842           -1.850180 -1.078081  1.375073
# 20768           1.647343           -2.477496  0.372658  1.417830
# 27674           1.502378           -2.437469 -0.285504  1.345429
# 34645           1.516220           -2.173876 -0.402512  1.379214
# ...                  ...                 ...       ...       ...
# 3489011         0.976088           -1.817453 -0.962849  0.467582
# 3500193         0.828359           -2.137828 -0.625897  0.377683
# 3511774         1.099873           -2.078233 -0.301605  0.480107
# 3522818         0.510220           -2.027397 -0.343166  0.397047
# 3533395         0.754460           -1.877322 -0.607800  0.542895
#
#          Sing-Plural.M  period_int  period_str
# 6890          0.460143        1720   1720-1725
# 13793         0.494944        1720   1720-1725
# 20768         0.536341        1720   1720-1725
# 27674         0.533547        1720   1720-1725
# 34645         0.519481        1720   1720-1725
# ...                ...         ...         ...
# 3489011      -0.095407        1895   1895-1900
# 3500193      -0.229678        1895   1895-1900
# 3511774      -0.136159        1895   1895-1900
# 3522818      -0.251059        1895   1895-1900
# 3533395      -0.162129        1895   1895-1900
#
# [360 rows x 23 columns]

# %%
for i,dfword in tqdm(df.groupby('word')):
    if i=='virtue': break
dfword
# Out:
#  97%|█████████▋| 11312/11678 [00:02<00:00, 5351.80it/s]
#         corpus     period     run    word  Abs-Conc.Median  Woman-Man.VG  \
# 6890       bpo  1700-1770  run_01  virtue         3.214739     -0.055065
# 13793      bpo  1700-1770  run_02  virtue         3.426751     -0.575663
# 20768      bpo  1700-1770  run_03  virtue         3.285548      1.083244
# 27674      bpo  1700-1770  run_04  virtue         3.090393      1.627666
# 34645      bpo  1700-1770  run_05  virtue         2.864174      0.091354
# ...        ...        ...     ...     ...              ...           ...
# 3489011    bpo  1830-1900  run_06  virtue         2.075567      0.081599
# 3500193    bpo  1830-1900  run_07  virtue         2.040826     -0.015448
# 3511774    bpo  1830-1900  run_08  virtue         2.446604      0.236667
# 3522818    bpo  1830-1900  run_09  virtue         2.116359      0.783226
# 3533395    bpo  1830-1900  run_10  virtue         1.644468     -0.194101
#
#          Human-Object.VG  Pleasure-Pain.HGI  Interp-Desc.HGI  Polit-Acad.HGI  \
# 6890            1.381495           2.572173         2.845677        1.558998
# 13793           2.026422           3.071403         3.055524        1.234054
# 20768           1.714781           2.420538         2.791909        1.790631
# 27674           1.881941           1.783067         2.609544        1.351938
# 34645           1.674049           2.071734         2.518239        1.389316
# ...                  ...                ...              ...             ...
# 3489011         1.128639           1.710345         1.406778       -1.219324
# 3500193         1.149327           1.871244         1.653688       -0.984135
# 3511774         1.871441           1.457747         1.879064       -0.553039
# 3522818         1.321273           1.838180         1.898465       -0.730975
# 3533395         0.950671           1.503685         1.283423       -0.666407
#
#          ...  Virtue-Vice.HGI  Collective-Indiv.RH  Judg-Perc.HGI  \
# 6890     ...         2.805773             1.113559       0.046696
# 13793    ...         3.345770             0.401270      -0.324064
# 20768    ...         2.765761             1.978974       0.215037
# 27674    ...         2.420377             0.445426      -0.509606
# 34645    ...         1.980953             1.054147      -0.099164
# ...      ...              ...                  ...            ...
# 3489011  ...         2.402779            -0.545846      -2.313037
# 3500193  ...         2.663170             0.068328      -1.312321
# 3511774  ...         2.196886            -0.368364      -1.410475
# 3522818  ...         2.270594             0.367582      -1.046473
# 3533395  ...         2.057910             0.040414      -1.676688
#
#          Strong-Weak.HGI  Active-Passive.HGI  Ambig.NX    Freq.M  \
# 6890            2.234454           -2.549791  0.298927  1.268937
# 13793           2.097842           -1.850180 -1.078081  1.375073
# 20768           1.647343           -2.477496  0.372658  1.417830
# 27674           1.502378           -2.437469 -0.285504  1.345429
# 34645           1.516220           -2.173876 -0.402512  1.379214
# ...                  ...                 ...       ...       ...
# 3489011         0.976088           -1.817453 -0.962849  0.467582
# 3500193         0.828359           -2.137828 -0.625897  0.377683
# 3511774         1.099873           -2.078233 -0.301605  0.480107
# 3522818         0.510220           -2.027397 -0.343166  0.397047
# 3533395         0.754460           -1.877322 -0.607800  0.542895
#
#          Sing-Plural.M  period_int  period_str
# 6890          0.460143        1720   1720-1725
# 13793         0.494944        1720   1720-1725
# 20768         0.536341        1720   1720-1725
# 27674         0.533547        1720   1720-1725
# 34645         0.519481        1720   1720-1725
# ...                ...         ...         ...
# 3489011      -0.095407        1895   1895-1900
# 3500193      -0.229678        1895   1895-1900
# 3511774      -0.136159        1895   1895-1900
# 3522818      -0.251059        1895   1895-1900
# 3533395      -0.162129        1895   1895-1900
#
# [360 rows x 23 columns]

# %%
from scipy.stats import mannwhitneyu

# %%
period1='1700-1770'
period2='1770-1830'
period3='1830-1900'

def ttest_word_df(dfword,min_n=20):
    grp1=dfword.query(f'period=="{period1}"')
    grp2=dfword.query(f'period=="{period2}"')
    grp3=dfword.query(f'period=="{period3}"')
    
    cmp={
        'Before-v-After':(grp1,grp3),
        'Before-v-During':(grp1,grp2),
        'During-v-After':(grp2,grp3)
    }
    o=[]
    for cmpname,(g1,g2) in cmp.items():
        if not len(g1) or not len(g2): continue
        vecnames = {c for c in g1.columns if c[0]==c[0].upper()} & {c for c in g2.columns if c[0]==c[0].upper()}
        for vecname in vecnames:
            a=g1[vecname]
            b=g2[vecname]
            if len(a)<min_n or len(b)<min_n: continue
            t,p = ttest_ind(a,b)
            #nstat1,np1 = normaltest(a)
            #nstat2,np2 = normaltest(b)
            mw,mw_p = mannwhitneyu(a,b)
            
            odx=dict(
                period_cmp=cmpname,
                vector=vecname,
#                 t=t,
#                 p=p,
                n1=len(a),
                n2=len(b),
                avg1=a.mean(),
                avg2=b.mean(),
                avg_diff=b.mean() - a.mean(),
                mw=mw,
                mw_p=mw_p
#                 normality1=nstat1,
#                 normality1_p=np1,
#                 normality2=nstat2,
#                 normality2_p=np2,
            )
            o.append(odx)
    odf=pd.DataFrame(o)
#     if len(odf):
#         display(dfword)
#         display(odf)
#         stop
#     odf['avg_diff_abs']=odf.avg_diff.apply(abs)
#     odf['is_signif']=odf.mw_p<=0.01
    return odf

# %%
dfword=ttest_word_df(df[df.word=='station']).sort_values('avg_diff')
dfword
# Out:
#          period_cmp               vector   n1   n2      avg1      avg2  \
# 49   During-v-After      Virtue-Vice.HGI  120  140  1.871378 -0.294399
# 15   Before-v-After      Virtue-Vice.HGI  100  140  1.809140 -0.294399
# 37   During-v-After          Pos-Neg.HGI  120  140  1.547652 -0.509102
# 13   Before-v-After    Pleasure-Pain.HGI  100  140  1.731376 -0.291203
# 3    Before-v-After          Pos-Neg.HGI  100  140  1.509316 -0.509102
# 47   During-v-After    Pleasure-Pain.HGI  120  140  1.605966 -0.291203
# 4    Before-v-After      Abs-Conc.Median  100  140  1.075546 -0.800612
# 38   During-v-After      Abs-Conc.Median  120  140  0.881545 -0.800612
# 43   During-v-After      Interp-Desc.HGI  120  140  0.818561 -0.752247
# 9    Before-v-After      Interp-Desc.HGI  100  140  0.813530 -0.752247
# 14   Before-v-After      Human-Object.VG  100  140  1.057754 -0.087404
# 48   During-v-After      Human-Object.VG  120  140  1.029285 -0.087404
# 40   During-v-After      Strong-Weak.HGI  120  140  1.985830  1.120741
# 2    Before-v-After       Qual-Quant.HGI  100  140 -0.771107 -1.611572
# 46   During-v-After       Time-Space.HGI  120  140  0.512181 -0.125454
# 12   Before-v-After       Time-Space.HGI  100  140  0.502636 -0.125454
# 36   During-v-After       Qual-Quant.HGI  120  140 -1.149988 -1.611572
# 35   During-v-After             Ambig.NX  120  140  0.286768 -0.171184
# 19  Before-v-During       Qual-Quant.HGI  100  120 -0.771107 -1.149988
# 16   Before-v-After        Judg-Perc.HGI  100  140 -0.817406 -1.179416
# 50   During-v-After        Judg-Perc.HGI  120  140 -0.856735 -1.179416
# 6    Before-v-After      Strong-Weak.HGI  100  140  1.374624  1.120741
# 10   Before-v-After         Woman-Man.VG  100  140 -0.160530 -0.411841
# 1    Before-v-After             Ambig.NX  100  140  0.076311 -0.171184
# 44   During-v-After         Woman-Man.VG  120  140 -0.213671 -0.411841
# 21  Before-v-During      Abs-Conc.Median  100  120  1.075546  0.881545
# 25  Before-v-During       Polit-Acad.HGI  100  120  1.098568  0.920620
# 17  Before-v-During  Collective-Indiv.RH  100  120 -1.023196 -1.154956
# 30  Before-v-During    Pleasure-Pain.HGI  100  120  1.731376  1.605966
# 27  Before-v-During         Woman-Man.VG  100  120 -0.160530 -0.213671
# 33  Before-v-During        Judg-Perc.HGI  100  120 -0.817406 -0.856735
# 31  Before-v-During      Human-Object.VG  100  120  1.057754  1.029285
# 26  Before-v-During      Interp-Desc.HGI  100  120  0.813530  0.818561
# 29  Before-v-During       Time-Space.HGI  100  120  0.502636  0.512181
# 20  Before-v-During          Pos-Neg.HGI  100  120  1.509316  1.547652
# 32  Before-v-During      Virtue-Vice.HGI  100  120  1.809140  1.871378
# 22  Before-v-During        Sing-Plural.M  100  120 -0.180775  0.009722
# 18  Before-v-During             Ambig.NX  100  120  0.076311  0.286768
# 24  Before-v-During               Freq.M  100  120  0.087764  0.406076
# 28  Before-v-During   Active-Passive.HGI  100  120 -0.461426  0.032356
# 0    Before-v-After  Collective-Indiv.RH  100  140 -1.023196 -0.509901
# 8    Before-v-After       Polit-Acad.HGI  100  140  1.098568  1.625268
# 39   During-v-After        Sing-Plural.M  120  140  0.009722  0.559396
# 23  Before-v-During      Strong-Weak.HGI  100  120  1.374624  1.985830
# 34   During-v-After  Collective-Indiv.RH  120  140 -1.154956 -0.509901
# 42   During-v-After       Polit-Acad.HGI  120  140  0.920620  1.625268
# 5    Before-v-After        Sing-Plural.M  100  140 -0.180775  0.559396
# 41   During-v-After               Freq.M  120  140  0.406076  1.332543
# 7    Before-v-After               Freq.M  100  140  0.087764  1.332543
# 45   During-v-After   Active-Passive.HGI  120  140  0.032356  1.460404
# 11   Before-v-After   Active-Passive.HGI  100  140 -0.461426  1.460404
#
#     avg_diff      mw          mw_p
# 49 -2.165776  1534.0  3.397985e-30
# 15 -2.103538  1507.0  1.918766e-25
# 37 -2.056754  1533.0  3.334253e-30
# 13 -2.022580   843.0  1.821795e-31
# 3  -2.018418  1510.0  2.035634e-25
# 47 -1.897169  1153.0  2.055364e-33
# 4  -1.876157   491.0  6.218272e-35
# 38 -1.682156   887.0  9.212646e-36
# 43 -1.570808  1208.0  6.138449e-33
# 9  -1.565777  1270.0  1.625357e-27
# 14 -1.145158  1457.0  7.129107e-26
# 48 -1.116689  1443.0  5.999427e-31
# 40 -0.865089  3461.0  1.544659e-16
# 2  -0.840465  2149.0  2.912080e-20
# 46 -0.637635  2605.0  4.583926e-22
# 12 -0.628090  2382.0  1.544621e-18
# 36 -0.461584  4237.0  2.868205e-12
# 35 -0.457952  5556.0  1.275455e-06
# 19 -0.378880  4102.0  2.714801e-05
# 16 -0.362010  5920.0  2.088390e-02
# 50 -0.322680  5091.0  2.209032e-08
# 6  -0.253883  4913.0  4.161132e-05
# 10 -0.251311  5924.0  2.126570e-02
# 1  -0.247495  5512.0  2.513703e-03
# 44 -0.198170  6521.0  9.430244e-04
# 21 -0.194001  4613.0  1.592306e-03
# 25 -0.177948  4837.0  6.702121e-03
# 17 -0.131761  5485.0  1.368825e-01
# 30 -0.125411  5092.0  2.677777e-02
# 27 -0.053141  5896.0  4.128721e-01
# 33 -0.039330  5741.0  2.912024e-01
# 31 -0.028469  5863.0  3.857705e-01
# 26  0.005031  5737.0  2.882910e-01
# 29  0.009544  5992.0  4.936356e-01
# 20  0.038336  5712.0  2.704132e-01
# 32  0.062238  5663.0  2.370588e-01
# 22  0.190497  2618.0  3.167919e-13
# 18  0.210457  5287.0  6.480844e-02
# 24  0.318312  2719.0  1.494845e-12
# 28  0.493782  3124.0  4.776625e-10
# 0   0.513295  4725.0  8.954845e-06
# 8   0.526699  3379.0  4.308574e-12
# 39  0.549674   484.0  1.766365e-39
# 23  0.611206  1847.0  5.090366e-19
# 34  0.645056  4777.0  1.031788e-09
# 42  0.704647  2932.0  7.489040e-20
# 5   0.740171     0.0  4.367025e-40
# 41  0.926467   283.0  2.095594e-41
# 7   1.244779     0.0  4.367025e-40
# 45  1.428048   394.0  2.458657e-40
# 11  1.921830   266.0  3.006357e-37

# %%
def ttest_vector_scores(force=False,num_proc=1,**attrs):
    if not force and os.path.exists(FN_VECTOR_SCORES_TTEST): return read_df(FN_VECTOR_SCORES_TTEST)
    
    df=get_vector_scores()
    ttests=pmap_groups(
        ttest_word_df,
        df.groupby('word'),
        num_proc=num_proc
    )
    ttests['mw_perc']=ttests.mw.rank(ascending=False) / len(ttests) * 100
    odf=ttests.reset_index().set_index(['word','vector','period_cmp']).sort_values('mw')
    odf=pd.concat(
        vdf.assign(mw_perc_vec=vdf.mw.rank(ascending=False) / len(vdf) * 100)
        for i,vdf in odf.groupby('vector')
    )
    odf=pd.concat(
        vdf.assign(mw_perc_vec_cmp=vdf.mw.rank(ascending=False) / len(vdf) * 100)
        for i,vdf in odf.groupby(['vector','period_cmp'])
    )
    odf=pd.concat(
        vdf.assign(
            avg1_perc_vec=(vdf.avg1.rank(ascending=False) / len(vdf) * 100),
            avg2_perc_vec=(vdf.avg2.rank(ascending=False) / len(vdf) * 100),
        )
        for i,vdf in odf.groupby('vector')
    )
    odf=odf.sort_index()
    odf.to_pickle(FN_VECTOR_SCORES_TTEST)
    
    # add to db
    with get_veclib('ttest') as vl:
        for w,wdf in tqdm(odf.groupby('word'),desc='Adding to db'):
            vl[w]=wdf
        print('Committing')
        vl.commit()
        print('Done')
    
    return odf

# %%
ttests = ttest_vector_scores(num_proc=4,force=True)
ttests
# Out:
# Mapping ttest_word_df [x4]: 100%|██████████| 11678/11678 [02:35<00:00, 75.08it/s]
# Adding to db: 100%|██████████| 10801/10801 [00:16<00:00, 664.98it/s]
# [Koselleck] (17:49:31) Committing (+831.4s)
# [Koselleck] (17:49:32) Done (+0.9s)
#                                                   n1     n2      avg1  \
# word        vector              period_cmp
# abandonment Abs-Conc.Median     During-v-After  57.0  140.0  1.298035
#             Active-Passive.HGI  During-v-After  57.0  140.0 -0.076074
#             Ambig.NX            During-v-After  57.0  140.0  0.656615
#             Collective-Indiv.RH During-v-After  57.0  140.0  0.090856
#             Freq.M              During-v-After  57.0  140.0 -0.374268
# ...                                              ...    ...       ...
# zoology     Sing-Plural.M       During-v-After  92.0  139.0       NaN
#             Strong-Weak.HGI     During-v-After  92.0  139.0  1.074550
#             Time-Space.HGI      During-v-After  92.0  139.0  0.230915
#             Virtue-Vice.HGI     During-v-After  92.0  139.0  1.000916
#             Woman-Man.VG        During-v-After  92.0  139.0 -1.234857
#
#                                                     avg2  avg_diff      mw  \
# word        vector              period_cmp
# abandonment Abs-Conc.Median     During-v-After  1.471056  0.173021  3074.0
#             Active-Passive.HGI  During-v-After -0.412245 -0.336172  2726.0
#             Ambig.NX            During-v-After  0.624658 -0.031957  3981.0
#             Collective-Indiv.RH During-v-After  0.183857  0.093001  3776.0
#             Freq.M              During-v-After -0.350042  0.024226  2410.0
# ...                                                  ...       ...     ...
# zoology     Sing-Plural.M       During-v-After       NaN       NaN  1566.0
#             Strong-Weak.HGI     During-v-After  1.542408  0.467858  3260.0
#             Time-Space.HGI      During-v-After  0.346584  0.115669  5465.0
#             Virtue-Vice.HGI     During-v-After  1.288035  0.287120  4247.0
#             Woman-Man.VG        During-v-After -1.655741 -0.420884  3508.0
#
#                                                         mw_p    mw_perc  \
# word        vector              period_cmp
# abandonment Abs-Conc.Median     During-v-After  5.818143e-03  61.483485
#             Active-Passive.HGI  During-v-After  2.488190e-04  66.536779
#             Ambig.NX            During-v-After  4.906557e-01  47.435068
#             Collective-Indiv.RH During-v-After  2.781402e-01  50.706802
#             Freq.M              During-v-After  6.718183e-06  70.882185
# ...                                                      ...        ...
# zoology     Sing-Plural.M       During-v-After  1.382250e-22  82.768852
#             Strong-Weak.HGI     During-v-After  1.469611e-10  58.663184
#             Time-Space.HGI      During-v-After  3.092591e-02  23.148135
#             Virtue-Vice.HGI     During-v-After  7.910287e-06  43.133571
#             Woman-Man.VG        During-v-After  3.253352e-09  54.870254
#
#                                                 mw_perc_vec  mw_perc_vec_cmp  \
# word        vector              period_cmp
# abandonment Abs-Conc.Median     During-v-After    62.735264        73.795125
#             Active-Passive.HGI  During-v-After    65.326937        76.446781
#             Ambig.NX            During-v-After    68.753984        82.768887
#             Collective-Indiv.RH During-v-After    59.187439        79.907890
#             Freq.M              During-v-After    46.960446        54.168217
# ...                                                     ...              ...
# zoology     Sing-Plural.M       During-v-After    49.183078        40.858764
#             Strong-Weak.HGI     During-v-After    60.177140        72.948456
#             Time-Space.HGI      During-v-After    28.132653        52.242278
#             Virtue-Vice.HGI     During-v-After    42.807059        54.791589
#             Woman-Man.VG        During-v-After    65.402422        78.247116
#
#                                                 avg1_perc_vec  avg2_perc_vec
# word        vector              period_cmp
# abandonment Abs-Conc.Median     During-v-After      13.060690      10.685409
#             Active-Passive.HGI  During-v-After      49.904385      66.226054
#             Ambig.NX            During-v-After       2.086758       4.153387
#             Collective-Indiv.RH During-v-After      48.210152      39.319623
#             Freq.M              During-v-After      75.223941      63.381085
# ...                                                       ...            ...
# zoology     Sing-Plural.M       During-v-After            NaN            NaN
#             Strong-Weak.HGI     During-v-After      16.271346      10.527728
#             Time-Space.HGI      During-v-After      32.012614      30.865233
#             Virtue-Vice.HGI     During-v-After      19.857752      16.073406
#             Woman-Man.VG        During-v-After      92.803704      96.893347
#
# [506719 rows x 12 columns]

# %%
# odf1

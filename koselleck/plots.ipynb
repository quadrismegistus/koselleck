# %% [markdown]
# # Dashboard

# %%
from ipynb.fs.full.koselleck import *
# Out:
# [Koselleck] (14:59:34) Alles bereit (+0.0s)

# %% [markdown]
# ## Neighborhoods

# %%
plot_nbrs('virtue')
# Out:
# <ggplot: (8788229161325)>

# %% [markdown]
# ## Historical semantic distance matrix

# %%
res=interact_manual(plot_historical_semantic_distance_matrix, words='ancestor')

# %%
# plot_historical_semantic_distance_matrix('station',force=True,k=50)

# %%
# Corp stat

# %%
import lltk

# %%
C=lltk.load('BPO')

# %%
C.meta
# Out:
#                            author  \
# id
# 1010/Advertisement/2032695
# 1010/Advertisement/2032690
# 1010/Unknown/2032695
# 1010/News/2032690
# 1010/News/2032695
# ...                           ...
# 1996/Advertisement/2032697
# 1996/Unknown/2032697
# 1996/Review/2032697
# 1997/News/2032690
# 1997/Unknown/2032690
#
#                                                                         title  \
# id
# 1010/Advertisement/2032695                                     Advertisements
# 1010/Advertisement/2032690                                 MAPPIN & WEBB Ltd.
# 1010/Unknown/2032695        THE Old Etonians beat Edinburgh University by ...
# 1010/News/2032690           GIVEN COMING-OF,-AGE FESTIVITIES, JUST LIKE A ...
# 1010/News/2032695                                                     Graphic
# ...                                                                       ...
# 1996/Advertisement/2032697                                             TURKEY
# ...

# %%
C.meta.query('1700<=year<1900')
# Out:
#                                author  \
# id
# 1700/Review/1771
# 1700/Poem/2945
# 1700/Front_Matter/1771
# 1700/Unknown/1771
# 1700/Unknown/2985
# ...                               ...
# 1899/General_Information/3048
# 1899/Back_Matter/2974
# 1899/Advertisement/2686
# 1899/General_Information/16474
# 1899/Undefined/2032690
#
#                                                                             title  \
# id
# 1700/Review/1771                Spicilegium SS. Patrum, ut &amp; H reticorum S...
# 1700/Poem/2945                  A SONG Set by Mr. Nicola, being the last he di...
# 1700/Front_Matter/1771                                               Front matter
# 1700/Unknown/1771                   Melanges d&apos;Histoire &amp; de Literature:
# 1700/Unknown/2985                                                   Untitled item
# ...                                                                           ...
# ...

# %%
lltk.pd.to_numeric(C.meta.num_words).sum()
# Out:
# 77270342

# %%
C.meta.iloc[0]
# Out:
# author
# title                                                           Advertisements
# year                                                                      1010
# NumericPubDate                                                           10101
# RecordID                                                            1618364638
# Publication_PublicationID                                              2032695
# Publication_Title                       Illustrated Sporting and Dramatic News
# Publication_Qualifier                                                   London
# Publisher                                              Illustrated London News
# VolumeIssue
# StartPage                                                                  239
# EndPage
# ObjectType                                                       Advertisement
# ISSN
# LanguageCode                                                               ENG
# ...

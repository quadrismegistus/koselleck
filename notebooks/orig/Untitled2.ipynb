# %%
from koselleck import *

# %%
m=get_any_model()

# %%
fieldd=get_fields()

# %%
odf=compute_vector_scores(m, fieldd['HGI.Time@'], fieldd['HGI.Space'])

# %%
odf[odf<-2]
# Out:
# blotches       -3.620938
# worms          -3.578484
# helps          -3.398205
# nerves         -3.369316
# burn           -3.323125
#                   ...
# rising         -2.002804
# rivers         -2.002365
# breast         -2.001892
# pill           -2.001426
# incomparable   -2.000592
# Length: 351, dtype: float64

# %%
fieldd['HGI.Active']
# Out:
# ['intense',
#  'pleased',
#  'concentration',
#  'evaluation',
#  'investigate',
#  'say',
#  'depart',
#  'defense',
#  'prepare',
#  'elevate',
#  'shun',
#  'astound',
#  'discriminate',
#  'go',
#  'publish',
#  'get',
#  'gamble',
#  'compare',
#  'dance',
#  'blackmail',
#  'modify',
#  'detract',
#  'harm',
#  'dispute',
#  'appointment',
#  'inflict',
#  'infect',
#  'assist',
#  'expend',
#  'plow',
#  'tamper',
#  'killer',
#  'consumption',
#  'argument',
#  'bomb',
#  'nominate',
#  'yelp',
#  'bolster',
#  'issue',
#  'outfit',
#  'trade',
#  'striven',
#  'celebrate',
#  'antagonism',
#  'endeavor',
#  'derive',
#  'collect',
#  'examine',
#  'drag',
#  'accelerate',
#  'petitioner',
#  'ask',
#  'haste',
#  'require',
#  'commend',
#  'impel',
#  'slander',
#  'wreck',
#  'associate',
#  'decease',
#  'discharge',
#  'repaid',
#  'performance',
#  'nail',
#  'enactment',
#  'mix',
#  'ascertainment',
#  'negotiate',
#  'rebel',
#  'reestablish',
#  'imprison',
# ...

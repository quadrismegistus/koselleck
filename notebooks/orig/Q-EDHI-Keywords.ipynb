# %%
from koselleck import *

# %%
kwdf=get_keywords()
keywords=set(x for x in kwdf[kwdf.in_author=='EDHI'].index if x and x!='?')
len(keywords), keywords
# Out:
# (12,
#  {'commerce',
#   'despotism',
#   'government',
#   'growth',
#   'improvement',
#   'irritability',
#   'irritation',
#   'liberty',
#   'republicanism',
#   'sensibility',
#   'sympathy',
#   'value'})

# %%
mostchanged = get_dfchange(words=keywords).sort_values('perc',ascending=False)
mostchanged
# Out:
#                   rank       perc      dist  rank_abstractness  \
# word
# irritability   816.425  82.876705  0.790106              618.2
# sympathy      1161.200  75.634863  0.510160              619.7
# irritation    2081.400  56.309440  0.096390              493.5
# value         2156.650  54.731531  0.074118              278.9
# government    2484.650  47.844352 -0.293472             1674.4
# growth        2492.950  47.667639 -0.265213             1400.8
# improvement   2495.025  47.624520 -0.316548             3499.0
# commerce      3115.275  34.599675 -0.545456             1297.6
# despotism     3481.600  26.908149 -0.578458             3946.2
# liberty       4127.625  13.340933 -0.913615             3032.7
# sensibility   4243.825  10.900330 -0.882613             4083.1
#
#               rank_noiseaware  rank_procrustes  rank_local  perc_abstractness  \
# word
# irritability            709.1            660.0      1278.4          87.039662
# ...

# %%
for i,w in enumerate(mostchanged.index):
    plot_word_info(w, title=f'{i+1}. {w}')
# Out:
# ## 1. irritability
# * Data from Sattelzeit binary model comparison
#     * **Clean** result for semantic change according to the noise aware data
#     * **73%** (**+Changed**) percentile for <u>local semantic change</u> (z=0.03)
# * Its neighborhoods:
#
# | Vor der Sattelzeit (1700-1770) | Nach der Sattelzeit (1830-1900) |
# | -------------- | -------------- |
# ...

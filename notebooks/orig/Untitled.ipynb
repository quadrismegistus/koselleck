# %% [markdown]
# # Test Models

# %%
from koselleck import *

# %%
m1=KeyedVectors.load('/home/ryan/github/koselleck/data/models/bpo/1700-1770/run_01/model.bin')
m2=KeyedVectors.load('/home/ryan/github/koselleck/data/models/bpo/1830-1900/run_01/model.bin')

# %%
df=measure_change(m1,m2, words=get_valid_words())
# Out:
# Measuring change in abstractness: 100%|██████████| 7020/7020 [00:00<00:00, 11885.17it/s]
# Aligning noise aware matrices: iter: 8; alpha: 0.885; sigma: 0.418; sigmay: 1.232: : 9it [00:02,  3.84it/s]
# ...
# Calculating local neighborhood distances [x1]: 100%|██████████| 7020/7020 [00:54<00:00, 129.46it/s]

# %%
df.sort_values('dist',ascending=False).head(25)
# Out:
#               rank       perc      dist  \
# word
# lack          9.50  99.878917  5.928402
# greed        18.50  99.750712  5.823917
# tact         12.50  99.836182  5.390863
# thrift       25.75  99.647436  4.841911
# feud         54.75  99.234330  4.503108
# employer    286.75  95.929487  4.274168
# feat        247.00  96.495726  4.155217
# case         58.50  99.180912  4.151635
# commune      94.00  98.675214  4.146000
# fee        1707.75  75.687322  4.139642
# serf         47.00  99.344729  4.042095
# fun         137.25  98.059117  4.039092
# role         44.25  99.383903  4.023539
# clutch      272.25  96.136040  3.957491
# germ         48.00  99.330484  3.941374
# drawbacks    49.25  99.312678  3.934243
# deficit     658.00  90.641026  3.903380
# fame       1124.75  83.992165  3.820702
# deals       131.75  98.137464  3.757032
# chants      783.75  88.849715  3.725042
# filter     1721.50  75.491453  3.714928
# muff       1755.75  75.003561  3.703975
# ...
